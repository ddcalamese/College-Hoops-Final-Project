# %%
# Final Project

#follow output from every line
from IPython.core.interactiveshell import InteractiveShell
InteractiveShell.ast_node_interactivity = "all"

# %%
import pandas as pd
import numpy as np

import matplotlib.pyplot as plt
import seaborn as sns

# %%
print('Enter your name:')
x = input()
print('Hello, ' + x)
# Out:
# Enter your name:
#  Darren
# Hello, Darren

# %%
print('Nice to meet you,' + x)
print("\nWe're gonna look at some college hoops data from the 2023 season")
# Out:
# Nice to meet you,Darren
#
# We're gonna look at some college hoops data from the 2023 season

# %%
# Reading in SEC Advanced data

BAMA_2023 = pd.read_csv("data/BAMA_2023.csv")
AUB_2023 = pd.read_csv("data/AUB_2023.csv")
ARK_2023 = pd.read_csv("data/ARK_2023.csv")
LSU_2023 = pd.read_csv("data/LSU_2023.csv")
TAM_2023 = pd.read_csv("data/TAM_2023.csv")
MIZZ_2023 = pd.read_csv("data/MIZZ_2023.csv")
MISS_2023 = pd.read_csv("data/MISS_2023.csv")
MSU_2023 = pd.read_csv("data/MSU_2023.csv")
UGA_2023 = pd.read_csv("data/UGA_2023.csv")
TENN_2023 = pd.read_csv("data/TENN_2023.csv")
KEN_2023 = pd.read_csv("data/KEN_2023.csv")
FLA_2023 = pd.read_csv("data/FLA_2023.csv")
USC_2023 = pd.read_csv("data/USC_2023.csv")
VAN_2023 = pd.read_csv("data/VAN_2023.csv")
#BAMA_2023

# %%
# Reading in Big 12 Advanced data

TEX_2023 = pd.read_csv("data/TEX_2023.csv")
OKLA_2023 = pd.read_csv("data/OKLA_2023.csv")
OSU_2023 = pd.read_csv("data/OSU_2023.csv")
KAN_2023 = pd.read_csv("data/KAN_2023.csv")
KSU_2023 = pd.read_csv("data/KSU_2023.csv")
TTU_2023 = pd.read_csv("data/TTU_2023.csv")
TCU_2023 = pd.read_csv("data/TCU_2023.csv")
BAY_2023 = pd.read_csv("data/BAY_2023.csv")
ISU_2023 = pd.read_csv("data/ISU_2023.csv")
WVA_2023 = pd.read_csv("data/WVA_2023.csv")

# %%
#Team Name & Records - Big 12 Conference play
# Calculate Win Percentage.....Add all 3 columns to df

KAN_2023['Team'] = "Kansas"
KAN_2023['Wins'] = 13
KAN_2023['Losses'] = 5
KAN_2023['pct'] = KAN_2023.Wins/(KAN_2023.Wins + KAN_2023.Losses)

KSU_2023['Team'] = "Kansas State"
KSU_2023['Wins'] = 11
KSU_2023['Losses'] = 7
KSU_2023['pct'] = KSU_2023.Wins/(KSU_2023.Wins + KSU_2023.Losses)

TEX_2023['Team'] = "Texas"
TEX_2023['Wins'] = 12
TEX_2023['Losses'] = 6
TEX_2023['pct'] = TEX_2023.Wins/(TEX_2023.Wins + TEX_2023.Losses)

BAY_2023['Team'] = "Baylor"
BAY_2023['Wins'] = 11
BAY_2023['Losses'] = 7
BAY_2023['pct'] = BAY_2023.Wins/(BAY_2023.Wins + BAY_2023.Losses)

TCU_2023['Team'] = "TCU"
TCU_2023['Wins'] = 9
TCU_2023['Losses'] = 9
TCU_2023['pct'] = TCU_2023.Wins/(TCU_2023.Wins + TCU_2023.Losses)

ISU_2023['Team'] = "Iowa State"
ISU_2023['Wins'] = 9
ISU_2023['Losses'] = 9
ISU_2023['pct'] = ISU_2023.Wins/(ISU_2023.Wins + ISU_2023.Losses)

OSU_2023['Team'] = "Oklahoma State"
OSU_2023['Wins'] = 8
OSU_2023['Losses'] = 10
OSU_2023['pct'] = OSU_2023.Wins/(OSU_2023.Wins + OSU_2023.Losses)

WVA_2023['Team'] = "West Virginia"
WVA_2023['Wins'] = 7
WVA_2023['Losses'] = 11
WVA_2023['pct'] = WVA_2023.Wins/(WVA_2023.Wins + WVA_2023.Losses)

TTU_2023['Team'] = "Texas Tech"
TTU_2023['Wins'] = 5
TTU_2023['Losses'] = 13
TTU_2023['pct'] = TTU_2023.Wins/(TTU_2023.Wins + TTU_2023.Losses)

OKLA_2023['Team'] = "Oklahoma"
OKLA_2023['Wins'] = 5
OKLA_2023['Losses'] = 13
OKLA_2023['pct'] = OKLA_2023.Wins/(OKLA_2023.Wins + OKLA_2023.Losses)

# %%
# Concatenate all Big 12 player data into one big table
print("Every player from the Big 12 conference.....\n")
BIG12_2023 = pd.concat([KAN_2023, TEX_2023, KSU_2023, BAY_2023, TCU_2023, TTU_2023, ISU_2023, OKLA_2023, OSU_2023, WVA_2023])
BIG12_2023
# Out:
# Every player from the Big 12 conference.....
#     Rk              Player Pos   G  GS   MP   PER    TS%   3PAr    FTr  ...  \
# 0    1   Dajuan Harris Jr.   G  18  18  648  16.8  0.523  0.311  0.119  ...
# 1    2        Jalen Wilson   F  18  18  648  20.3  0.525  0.384  0.387  ...
# 2    3         Gradey Dick   G  18  18  599  18.0  0.562  0.547  0.276  ...
# 3    4  Kevin McCullar Jr.   G  18  18  573  17.3  0.531  0.345  0.549  ...
# 4    5        KJ Adams Jr.   F  18  18  509  19.6  0.609  0.015  0.515  ...
# ..  ..                 ...  ..  ..  ..  ...   ...    ...    ...    ...  ...
# 9   10        Kobe Johnson   G  14   0  125   5.4  0.442  0.222  0.278  ...
# 10  11        Pat Suemnick   F  13   0   80  13.0  0.518  0.133  0.333  ...
# 11  12       Josiah Harris   F   6   0   31  22.1  0.685  0.600  0.200  ...
# 12  13          Jamel King   F   2   0    4  76.0  1.250  0.500  0.000  ...
# 13  14        Josiah Davis   G   1   0    2   0.0    NaN    NaN    NaN  ...
#
# ...

# %%
#Team Name & Records - SEC Conference play
# Calculate Win Percentage.....Add all 3 columns to df

BAMA_2023['Team'] = "Alabama"
BAMA_2023['Wins'] = 16
BAMA_2023['Losses'] = 2
BAMA_2023['pct'] = BAMA_2023.Wins/(BAMA_2023.Wins + BAMA_2023.Losses)

TAM_2023['Team'] = "Texas A&M"
TAM_2023['Wins'] = 15
TAM_2023['Losses'] = 3
TAM_2023['pct'] = TAM_2023.Wins/(TAM_2023.Wins + TAM_2023.Losses)

KEN_2023['Team'] = "Kentucky"
KEN_2023['Wins'] = 12
KEN_2023['Losses'] = 6
KEN_2023['pct'] = KEN_2023.Wins/(KEN_2023.Wins + KEN_2023.Losses)

MIZZ_2023['Team'] = "Missouri"
MIZZ_2023['Wins'] = 11
MIZZ_2023['Losses'] = 7
MIZZ_2023['pct'] = MIZZ_2023.Wins/(MIZZ_2023.Wins + MIZZ_2023.Losses)

TENN_2023['Team'] = "Tennessee"
TENN_2023['Wins'] = 11
TENN_2023['Losses'] = 7
TENN_2023['pct'] = TENN_2023.Wins/(TENN_2023.Wins + TENN_2023.Losses)

VAN_2023['Team'] = "Vanderbilt"
VAN_2023['Wins'] = 11
VAN_2023['Losses'] = 7
VAN_2023['pct'] = VAN_2023.Wins/(VAN_2023.Wins + VAN_2023.Losses)

AUB_2023['Team'] = "Auburn"
AUB_2023['Wins'] = 10
AUB_2023['Losses'] = 8
AUB_2023['pct'] = AUB_2023.Wins/(AUB_2023.Wins + AUB_2023.Losses)

FLA_2023['Team'] = "Florida"
FLA_2023['Wins'] = 9
FLA_2023['Losses'] = 9
FLA_2023['pct'] = FLA_2023.Wins/(FLA_2023.Wins + FLA_2023.Losses)

MSU_2023['Team'] = "MSU"
MSU_2023['Wins'] = 8
MSU_2023['Losses'] = 10
MSU_2023['pct'] = MSU_2023.Wins/(MSU_2023.Wins + MSU_2023.Losses)

ARK_2023['Team'] = "Arkansas"
ARK_2023['Wins'] = 8
ARK_2023['Losses'] = 10
ARK_2023['pct'] = ARK_2023.Wins/(ARK_2023.Wins + ARK_2023.Losses)

UGA_2023['Team'] = "Georgia"
UGA_2023['Wins'] = 6
UGA_2023['Losses'] = 12
UGA_2023['pct'] = UGA_2023.Wins/(UGA_2023.Wins + UGA_2023.Losses)

USC_2023['Team'] = "South Carolina"
USC_2023['Wins'] = 4
USC_2023['Losses'] = 14
USC_2023['pct'] = USC_2023.Wins/(USC_2023.Wins + USC_2023.Losses)

MISS_2023['Team'] = "Ole Miss"
MISS_2023['Wins'] = 3
MISS_2023['Losses'] = 15
MISS_2023['pct'] = MISS_2023.Wins/(MISS_2023.Wins + MISS_2023.Losses)

LSU_2023['Team'] = "LSU"
LSU_2023['Wins'] = 2
LSU_2023['Losses'] = 16
LSU_2023['pct'] = LSU_2023.Wins/(LSU_2023.Wins + LSU_2023.Losses)

# %%
# Concatenate all SEC player data into one big table
SEC_2023 = pd.concat([BAMA_2023, TAM_2023, KEN_2023, MIZZ_2023, TENN_2023, VAN_2023, AUB_2023, FLA_2023, MSU_2023, ARK_2023, UGA_2023, USC_2023, MISS_2023, LSU_2023])
#SEC_2023

# %%
# Remove all the NaN entries (I think they are ALL under "Awards") and replace with blank spaces

SEC_2023.fillna('', inplace=True)
BIG12_2023.fillna('', inplace=True)
# Out:
# C:\Users\Calam\AppData\Local\Temp\ipykernel_19532\2177384088.py:3: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   SEC_2023.fillna('', inplace=True)
# C:\Users\Calam\AppData\Local\Temp\ipykernel_19532\2177384088.py:4: FutureWarning: Setting an item of incompatible dtype is deprecated and will raise an error in a future version of pandas. Value '' has dtype incompatible with float64, please explicitly cast to a compatible dtype first.
#   BIG12_2023.fillna('', inplace=True)

# %%
print("Every player from the S-E-C.....\n")
SEC_2023
# Out:
# Every player from the S-E-C.....
#     Rk              Player Pos   G  GS   MP   PER    TS%   3PAr    FTr  ...  \
# 0    1      Brandon Miller   F  18  18  598  28.1  0.635  0.552  0.316  ...
# 1    2          Mark Sears   G  18  18  537  19.8  0.597  0.588   0.45  ...
# 2    3        Noah Clowney   F  18  18  487  20.2  0.585  0.443   0.45  ...
# 3    4       Jaden Bradley   G  18  18  371  13.1  0.477   0.13  0.772  ...
# 4    5     Charles Bediako   C  18  18  367  17.7  0.585  0.063  0.241  ...
# ..  ..                 ...  ..  ..  ..  ...   ...    ...    ...    ...  ...
# 8    9    Justice Williams   G  13   6  221   6.7  0.427  0.234  0.255  ...
# 9   10  Shawn Phillips Jr.   F  14   0   99  10.1  0.384    0.0  0.333  ...
# 10  11      Kendal Coleman   C   8   0   57   8.4  0.475    0.0    1.0  ...
# 11  12     Mwani Wilkinson   F   2   0   13  12.4    1.0    0.0    0.0  ...
# 12  13      Parker Edwards   G   1   1    6  56.1    1.5    1.0    0.0  ...
#
# ...

# %%
print("....as well as every player from the Big 12.....\n")
BIG12_2023
# Out:
# ....as well as every player from the Big 12.....
#     Rk              Player Pos   G  GS   MP   PER    TS%   3PAr    FTr  ...  \
# 0    1   Dajuan Harris Jr.   G  18  18  648  16.8  0.523  0.311  0.119  ...
# 1    2        Jalen Wilson   F  18  18  648  20.3  0.525  0.384  0.387  ...
# 2    3         Gradey Dick   G  18  18  599  18.0  0.562  0.547  0.276  ...
# 3    4  Kevin McCullar Jr.   G  18  18  573  17.3  0.531  0.345  0.549  ...
# 4    5        KJ Adams Jr.   F  18  18  509  19.6  0.609  0.015  0.515  ...
# ..  ..                 ...  ..  ..  ..  ...   ...    ...    ...    ...  ...
# 9   10        Kobe Johnson   G  14   0  125   5.4  0.442  0.222  0.278  ...
# 10  11        Pat Suemnick   F  13   0   80  13.0  0.518  0.133  0.333  ...
# 11  12       Josiah Harris   F   6   0   31  22.1  0.685    0.6    0.2  ...
# 12  13          Jamel King   F   2   0    4  76.0   1.25    0.5    0.0  ...
# 13  14        Josiah Davis   G   1   0    2   0.0                       ...
#
# ...

# %%
#BIG12_2023
#BIG12_2023[['Team','Wins','Losses','WS','WS/40']]
BIG12_2023_ADV_WS = BIG12_2023[['Team', 'WS']].groupby('Team').mean('WS')
#BIG12_2023_ADV_WS

# %%
BIG12_2023_ADV_WS_sum = BIG12_2023[['Team', 'WS']].groupby('Team').sum('WS')
#BIG12_2023_ADV_WS_sum

# %%
BIG12_2023_ADV_pct = BIG12_2023[['Team', 'pct']].groupby('Team').mean('pct')
#BIG12_2023_ADV_pct

# %%
SEC_2023_ADV_WS = SEC_2023[['Team', 'WS']].groupby('Team').mean('WS')
#SEC_2023_ADV_WS

# %%
SEC_2023_ADV_WS_sum = SEC_2023[['Team', 'WS']].groupby('Team').sum('WS')
#SEC_2023_ADV_WS_sum

# %%
SEC_2023_ADV_pct = SEC_2023[['Team', 'pct']].groupby('Team').mean('pct')
#SEC_2023_ADV_pct

# %%
SEC_2023_ADV_OWS = SEC_2023[['Team', 'OWS']].groupby('Team').mean('OWS')
#SEC_2023_ADV_OWS
SEC_2023_ADV_DWS = SEC_2023[['Team', 'DWS']].groupby('Team').mean('DWS')
#SEC_2023_ADV_DWS

# %%
BIG12_2023_ADV_OWS = BIG12_2023[['Team', 'OWS']].groupby('Team').mean('OWS')
#BIG12_2023_ADV_OWS
BIG12_2023_ADV_DWS = BIG12_2023[['Team', 'DWS']].groupby('Team').mean('DWS')
#BIG12_2023_ADV_DWS

# %%
BIG12_2023_ADV_ALL = pd.merge(BIG12_2023_ADV_WS, BIG12_2023_ADV_WS_sum, on=['Team'])
#BIG12_2023_ADV_ALL
BIG12_2023_ALL = pd.merge(BIG12_2023_ADV_ALL, BIG12_2023_ADV_pct, on=['Team'])
#BIG12_2023_ALL

# %%
SEC_2023_ADV_ALL = pd.merge(SEC_2023_ADV_WS, SEC_2023_ADV_WS_sum, on=['Team'])
#SEC_2023_ADV_ALL
SEC_2023_ALL = pd.merge(SEC_2023_ADV_ALL, SEC_2023_ADV_pct, on=['Team'])
#SEC_2023_ALL

# %%
BIG12_2023_OFF_DEF = pd.merge(BIG12_2023_ADV_OWS, BIG12_2023_ADV_DWS, on=['Team'])
#BIG12_2023_OFF_DEF
BIG12_2023_ALL = pd.merge(BIG12_2023_ALL, BIG12_2023_OFF_DEF, on=['Team'])
print("Team statistics for the 2022-23 season - Big 12")
BIG12_2023_ALL
# Out:
# Team statistics for the 2022-23 season - Big 12
#                     WS_x  WS_y       pct       OWS       DWS
# Team
# Baylor          0.738462   9.6  0.611111  0.800000 -0.053846
# Iowa State      0.883333  10.6  0.500000  0.566667  0.308333
# Kansas          0.707143   9.9  0.722222  0.535714  0.185714
# Kansas State    0.990000   9.9  0.611111  0.810000  0.190000
# Oklahoma        0.407692   5.3  0.277778  0.392308  0.038462
# Oklahoma State  0.471429   6.6  0.444444  0.364286  0.114286
# TCU             0.587500   9.4  0.500000  0.450000  0.137500
# Texas           0.916667  11.0  0.666667  0.725000  0.175000
# Texas Tech      0.484615   6.3  0.277778  0.469231  0.030769
# West Virginia   0.585714   8.2  0.388889  0.585714  0.028571

# %%
SEC_2023_OFF_DEF = pd.merge(SEC_2023_ADV_OWS, SEC_2023_ADV_DWS, on=['Team'])
#SEC_2023_OFF_DEF
SEC_2023_ALL = pd.merge(SEC_2023_ALL, SEC_2023_OFF_DEF, on=['Team'])
print("Team statistics for the 2022-23 season - SEC")
SEC_2023_ALL
# Out:
# Team statistics for the 2022-23 season - SEC
#                     WS_x  WS_y       pct       OWS           DWS
# Team
# Alabama         1.221429  17.1  0.888889  0.757143  4.500000e-01
# Arkansas        0.671429   9.4  0.444444  0.528571  1.642857e-01
# Auburn          0.685714   9.6  0.555556  0.542857  1.357143e-01
# Florida         0.620000   9.3  0.500000  0.460000  1.466667e-01
# Georgia         0.281818   3.1  0.333333  0.418182 -1.363636e-01
# Kentucky        0.771429  10.8  0.666667  0.735714  5.714286e-02
# LSU             0.153846   2.0  0.111111  0.323077 -1.769231e-01
# MSU             0.546667   8.2  0.444444  0.346667  1.933333e-01
# Missouri        0.546667   8.2  0.611111  0.633333 -7.333333e-02
# Ole Miss        0.423077   5.5  0.166667  0.430769 -2.135044e-18
# South Carolina  0.169231   2.2  0.222222  0.369231 -1.923077e-01
# Tennessee       1.021429  14.3  0.611111  0.635714  3.928571e-01
# Texas A&M       0.971429  13.6  0.833333  0.685714  2.714286e-01
# ...

# %%
sns.regplot(x="WS_x",y="pct", data=BIG12_2023_ALL)
# Out:
# <Axes: xlabel='WS_x', ylabel='pct'>

# %%
sns.regplot(x="WS_x",y="pct", data=SEC_2023_ALL)
# Out:
# <Axes: xlabel='WS_x', ylabel='pct'>

# %%
sns.regplot(x="WS_y",y="pct", data=BIG12_2023_ALL)
# Out:
# <Axes: xlabel='WS_y', ylabel='pct'>

# %%
sns.regplot(x="WS_y",y="pct", data=SEC_2023_ALL)
# Out:
# <Axes: xlabel='WS_y', ylabel='pct'>

# %%
print("SEC OWS and DWS vs win pct by team....there is a clear connection - stronger with the DWS")
sns.regplot(x="OWS",y="pct", data=SEC_2023_ALL)
sns.regplot(x="DWS",y="pct", data=SEC_2023_ALL)
# Out:
# SEC OWS and DWS vs win pct by team....there is a clear connection - stronger with the DWS
# <Axes: xlabel='OWS', ylabel='pct'>
# <Axes: xlabel='DWS', ylabel='pct'>

# %%
#sns.regplot(x="WS_y",y="pct", data=BIG12_2023_ALL)
print("Same for the Big 12....there is a clear connection")
sns.regplot(x="OWS",y="pct", data=BIG12_2023_ALL)
sns.regplot(x="DWS",y="pct", data=BIG12_2023_ALL)
# Out:
# Same for the Big 12....there is a clear connection
# <Axes: xlabel='OWS', ylabel='pct'>
# <Axes: xlabel='DWS', ylabel='pct'>

# %%
BIG12_big_data = BIG12_2023_ALL[['WS_x','WS_y','DWS','pct']]

#sns.pairplot(teams_selected_data)

sns.pairplot(BIG12_big_data, diag_kind='kde', kind="reg",
             plot_kws={'line_kws':{'color':'red'}, 'scatter_kws':{'alpha': 0.2}})

# %%
SEC_big_data = SEC_2023_ALL[['WS_x','WS_y','DWS','pct']]

#sns.pairplot(teams_selected_data)

sns.pairplot(SEC_big_data, diag_kind='kde', kind="reg",
             plot_kws={'line_kws':{'color':'red'}, 'scatter_kws':{'alpha': 0.2}})

# %%
# Players' WS vs pct data

#Find the best plot

# %%
SEC_2023_24 = SEC_2023.copy()
SEC_2023_24 = SEC_2023_24[(SEC_2023_24.WS > 1.5)]
SEC_2023_24.index = SEC_2023_24.Player

#SEC_2023_24
#fig1 = SEC_2023_24[['OWS','DWS','WS','pct']].sort_values(by='pct').plot.bar()
#fig1

# %%
BIG12_2023_24 = BIG12_2023.copy()
BIG12_2023_24 = BIG12_2023_24[(BIG12_2023_24.WS > 1.5)]
BIG12_2023_24.index = BIG12_2023_24.Player

#BIG12_2023_24
#fig2 = BIG12_2023_24[['OWS','DWS','WS','pct']].sort_values(by='pct').plot.bar()
#fig2

# %%
y='X'
#z=0
print('A part of my Final Project is to determine (visually...using the top 20 players)' + '\n' + 'the correlation between individual WS factors and win pct?' + '\n' )
print('Which Conference would you like to see final analysis?' + '\n' )
print('Type B for Big 12 Conference....Type S for Southeastern Conference...U for both\n')
y = input()

if y == 'B':
    print("\n\nYou chose the Big 12 Conference.\n\n")        
    BIG12_2023_24[['OWS','DWS','WS','pct']].sort_values(by='pct').plot.bar()
    print("Here are the top 20 players by WS for 2023. \nThere appears to be no correlation AT ALL with any of the categories and win percentage.")
elif y == 'S':
    print("\n\nYou chose the S-E-C.\n\n")    
    SEC_2023_24[['OWS','DWS','WS','pct']].sort_values(by='pct').plot.bar()
    print("Here are the top 20 players by WS for 2023. \nUnlike the Big 12, There appears to be a slight correlation \nbetween the DWS and win percentage....and a moderate connection between WS and win percentage.")
elif y == 'U':
    print("\n\nYou chose both. Look and compare.\n\n")    
    BIG12_2023_24[['OWS','DWS','WS','pct']].sort_values(by='pct').plot.bar()
    SEC_2023_24[['OWS','DWS','WS','pct']].sort_values(by='pct').plot.bar()
    print("The correlation between DWS and WS with win pct is a little stronger in the SEC than the Big 12")
else: print("Invalid Choice. ")
# Out:
# A part of my Final Project is to determine (visually...using the top 20 players)
# the correlation between individual WS factors and win pct?
#
# Which Conference would you like to see final analysis?
#
# Type B for Big 12 Conference....Type S for Southeastern Conference...U for both
#  U
# You chose both. Look and compare.
# <Axes: xlabel='Player'>
# <Axes: xlabel='Player'>
# The correlation between DWS and WS with win pct is a little stronger in the SEC than the Big 12

# %%
print('Thanks for viewing')
# Out:
# Thanks for viewing
